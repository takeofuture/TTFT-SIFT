# %%
# !pip install -q bitsandbytes==0.46.0 faiss-cpu==1.11.0 peft==0.15.2
# !pip install activeft
# Out:
# Requirement already satisfied: activeft in /usr/local/lib/python3.11/dist-packages (0.1.1)
# Requirement already satisfied: torch<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from activeft) (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.4.0->activeft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0.0,>=2.4.0->activeft) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0.0,>=2.4.0->activeft) (3.0.2)

# %%
import torch, bitsandbytes as bnb, faiss, transformers, peft, activeft
print(torch.__version__, torch.version.cuda)
print("bnb", bnb.__version__, "faiss", faiss.__version__, "tfm", transformers.__version__)
# Out:
# 2.6.0+cu124 12.4
# bnb 0.46.0 faiss 1.11.0 tfm 4.52.4

# %%
import warnings, logging
from transformers import logging as hf_logging

# 1. Python 標準 warnings を全面的に無効化
warnings.filterwarnings("ignore")

# 2. PyTorch 系の冗長ログを抑制（必要なら）
logging.getLogger("torch._dynamo").setLevel(logging.ERROR)
logging.getLogger("torch.utils.checkpoint").setLevel(logging.ERROR)

# 3. Hugging Face Transformers の INFO/WARNING を抑制
hf_logging.set_verbosity_error()

# %%
import math, copy, torch, faiss, numpy as np, bitsandbytes as bnb
from transformers import (AutoTokenizer, AutoModelForCausalLM,
                          BitsAndBytesConfig)
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training
from activeft.sift import Retriever
from activeft.acquisition_functions.vtl import VTL

# %%
# ---------- tiny corpus ----------
# https://kyoto-kaira.github.io/

RAW_PARAS = [
    "京都大学人工知能研究会 KaiRA は、AI・機械学習の専門書を輪読する自主ゼミ形式のサークルである。",
    "文理・大学を問わず多様なバックグラウンドの学生が参加している。",
    "AI を学びたい学生や一緒に AI を開発したい学生を歓迎している。",
    "書籍購入費や計算リソース費用の補助がある。",
    "活動の中心は輪読会と作業会である。",
    "興味のある本があればメンバー主導で勉強会を立ち上げられる。",
    "論文読み会や Kaggle・SIGNATE コンペへのチーム参加も行っている。",
    "会費は無料である。",
    "輪読会は毎週月曜・木曜の 18:40 から京都大学文学部教室とオンラインで開催される。",
    "コンペ練習会は毎週土曜 10:00 から行われる。",
    "論文読み会は月に一度、約 2 時間実施される。",
    "長期休暇と試験期間中は定期活動を休止する。",
    "KaiRA は毎年 11 月祭でポスター展示・AI デモ・会誌販売を行う。",
    "会長は工学部理工化学科の岡本和優である。",
    "副会長は理学部数理科学系の千葉一世である。",
    "会計は工学部情報学科の宮前明生である。",
    "広報は工学部情報学科の稲葉陽孔である。",
    "技術顧問には情報学研究科の鹿島久嗣教授が就任している。",
    "小島諒介准教授は医療データの時系列解析を専門とする。",
    "KaiRA は株式会社 Rist と株式会社スクラムサインから支援を受けている。",
    "創設者の金子英樹は、難解な数式に挫折する学生のために KaiRA を立ち上げた。",
    "歴代会長には金子英樹、大山百々勢、三宅大貴、松田拓巳が名を連ねる。",
    "松田拓巳は深層学習を用いた気象アルゴリズム研究に従事している。",
    "入会ステップ 1 は connpass で輪読会に申し込み見学することである。",
    "3〜4 月には新入会希望者向け説明会を実施し、最新情報は X で告知される。",
    "入会ステップ 2 は connpass の入会申請フォームに回答し、確認後 Slack 招待を受ける。",
    "会費は 0 円で、発表者には書籍代、Kaggle 参加者には計算リソース代が補助される。",
    "プログラミング初心者も参加可能で、Python を並行学習すると理解が深まる。",
    "他大学の学生もオンライン参加が可能である。",
    "事前学習には『ゼロから作る Deep Learning』の読書が推奨される。",
    "メンバーは学んだことを活かすためにソフトウェアプロジェクトの開発にも取り組んでいます。",
    "定期的な活動は大学の長期休暇期間や試験期間中は休止します。",
    "開催教室は文学部の空き状況に応じて変更になる場合があります。",
    "モデル学習の実験にかかる Google Colab Pro の料金は補助されます。",
    "学部・学年・バックグラウンドを問わず、どなたでも参加できます。",
    "サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。"
]

# %%
QUESTION = "KaiRA のモットーは何ですか?"

# %%
# ---------- 日本語 LLM (4-bit) ----------
DEV, BASE = "cuda", "elyza/ELYZA-japanese-Llama-2-7b-fast-instruct"
tok = AutoTokenizer.from_pretrained(BASE, use_fast=True)
tok.pad_token = tok.eos_token
bnb_cfg = BitsAndBytesConfig(load_in_4bit=True,
                             bnb_4bit_compute_dtype=torch.float16)
base = AutoModelForCausalLM.from_pretrained(BASE, device_map="auto",
                                            quantization_config=bnb_cfg)
base = prepare_model_for_kbit_training(base)

lora_cfg = LoraConfig(
    r               = 8,
    lora_alpha      = 16,
    lora_dropout    = 0.05,
    target_modules  = [
        "q_proj", "k_proj", "v_proj", "o_proj",  # Attention
        "gate_proj", "up_proj", "down_proj"      # FFN
    ],
    bias      = "none",
    task_type = "CAUSAL_LM",
)
model = get_peft_model(copy.deepcopy(base), lora_cfg).eval()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
@torch.no_grad()
def embed(text: str) -> torch.Tensor:
    ids = tok(text, truncation=True, max_length=128,
              return_tensors="pt").input_ids.to(DEV)
    vec = model.base_model.get_input_embeddings()(ids).mean(1)
    return (vec / vec.norm(dim=-1, keepdim=True)).squeeze(0).cpu()

# ---------- bpb (bits-per-byte) 計算 ----------
def calc_bpb(texts):
    """
    texts: list[str]
    戻り値: Bits-per-byte (float)
    """
    loss_sum = 0.0
    byte_sum = 0
    for t in texts:
        enc = tok(t, return_tensors="pt").to(DEV)
        with torch.no_grad():
            loss_val = model(**enc, labels=enc.input_ids).loss.item()
        loss_sum += loss_val * enc.input_ids.size(1)
        byte_sum += len(t.encode("utf-8"))
    return loss_sum / byte_sum / math.log(2)   # nat → bit

# %%
# ---------- build Faiss index ----------
doc_emb = torch.stack([embed(t) for t in RAW_PARAS]).numpy().astype("float32")
index = faiss.IndexFlatIP(doc_emb.shape[1]); index.add(doc_emb)

# ---------- Pre-FT ----------
pre_bpb = calc_bpb([QUESTION])
answer_pre = tok.decode(
    model.generate(**tok(QUESTION, return_tensors="pt").to(DEV),
                   max_new_tokens=40, do_sample=False)[0],
    skip_special_tokens=True
)

# %%
print("===== 事前状態 (Pre-FT) =====")
print("質問:", QUESTION)
print("回答:", answer_pre.strip())
print(f"bpb  : {pre_bpb:.3f}")
print("=============================")
# Out:
# ===== 事前状態 (Pre-FT) =====
# 質問: KaiRA のモットーは何ですか?
# 回答: KaiRA のモットーは何ですか?
#  Unterscheidung は何ですか?
#  「KaiRA」は、2016年10月に設立された、京都大学と株式会社サイバーダインの共同出
# bpb  : 2.438
# =============================

# %% [markdown]
# ### λ（ラムダ）と “探索ノイズ” の関係
#
# | 役割 | 数式／処理 | 直感 |
# |------|-----------|------|
# | **① λ → σ<sub>noise</sub>** | $$\displaystyle \sigma_{\text{noise}}=\max\!\bigl(\sqrt{\lambda},\;\varepsilon\bigr),\qquad \varepsilon=10^{-6}$$ | λ を **分散** とみなし、その平方根を **標準偏差** に変換 |
# | **② VTL のスコア** | $$\displaystyle a(x)=\mu(x)+\sigma_{\text{noise}}\;\xi,\qquad \xi\sim\mathcal N(0,1)$$ | 類似度 $$\mu(x)$$ にガウス雑音を足して **多様性 (exploration)** を注入 |
# | **③ λ を掃引（sweep）する意味** | <div style="text-align:center">$$\lambda\!\to\!0$$ ⇒ $$\sigma_{\text{noise}}\approx0$$ → **Nearest&nbsp;Neighbor**<br>$$\lambda\!\uparrow$$ ⇒ ノイズ↑ → **情報利得最大化 (SIFT)**</div> | 小さい λ : *relevance* 重視<br>大きい λ : *diversity* 重視 |
#
# #### ✅ 使い分けの目安
# * **FAQ のようなピンポイント質問** → $$\lambda\approx 0.001\text{–}0.1$$
# * **幅広い知識を引き出したい** → $$\lambda\approx 1\text{–}10$$
# ---
#
#
#     ...

# %%
# ---------- sweep λ ----------
noise_floor = 1e-6
STEPS = 10
for lam in [0, 0.001, 0.01, 0.1, 1, 10, 100]:
    print(f"\nλ = {lam}")
    std = max(np.sqrt(lam), noise_floor)
    vtl = VTL(target=torch.empty(0), noise_std=std)
    retr = Retriever(index, acquisition_function=vtl,
                     device=torch.device(DEV))

    # K=None なら全件対象; (scores, idx, _, _)
    _, idx, _, _ = retr.search(embed(QUESTION)[None, :].numpy(), N=8, K=None)
    idx = idx.tolist()
    sel = [RAW_PARAS[i] for i in idx]

    print("選択された文書 ID:", idx, sel)
    print("-------- Fine-Tuning --------")
    ft_texts = sel + [f"### Question: {QUESTION}\n### Answer:"]
    batch = tok(ft_texts, padding=True, truncation=True,
                max_length=128, return_tensors="pt").to(DEV)
    labels = batch.input_ids.clone()
    labels[labels == tok.pad_token_id] = -100

    opt = bnb.optim.Adam8bit(model.parameters(), lr=3e-4)
    model.train()
    for step in range(STEPS):
        loss = model(**batch, labels=labels).loss
        loss.backward(); opt.step(); opt.zero_grad()
        step_bpb = calc_bpb([QUESTION])
        print(f" step {step+1:02d}/{STEPS:02d} | "
              f"loss = {loss.item():.4f} | bpb = {step_bpb:.3f}")

    model.eval(); torch.cuda.empty_cache()

    # ---------- Post-FT ----------
    post_bpb = calc_bpb([QUESTION])
    answer_post = tok.decode(
        model.generate(**tok(QUESTION, return_tensors="pt").to(DEV),
                       max_new_tokens=40, do_sample=False)[0],
        skip_special_tokens=True
    )

    delta = pre_bpb - post_bpb
    print("-------- 結果 --------")
    print("回答:", answer_post.strip())
    print(f"bpb  : {post_bpb:.3f}  (Δ = {delta:+.3f}   ※マイナス=改善)")
    print("----------------------")
# Out:
# λ = 0
# 選択された文書 ID: [35, 12, 19, 2, 20, 8, 33, 23] ['サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'KaiRA は毎年 11 月祭でポスター展示・AI デモ・会誌販売を行う。', 'KaiRA は株式会社 Rist と株式会社スクラムサインから支援を受けている。', 'AI を学びたい学生や一緒に AI を開発したい学生を歓迎している。', '創設者の金子英樹は、難解な数式に挫折する学生のために KaiRA を立ち上げた。', '輪読会は毎週月曜・木曜の 18:40 から京都大学文学部教室とオンラインで開催される。', 'モデル学習の実験にかかる Google Colab Pro の料金は補助されます。', '入会ステップ 1 は connpass で輪読会に申し込み見学することである。']
# -------- Fine-Tuning --------
#  step 01/10 | loss = 3.8767 | bpb = 2.223
#  step 02/10 | loss = 3.2815 | bpb = 1.938
#  step 03/10 | loss = 2.6747 | bpb = 1.620
#  step 04/10 | loss = 2.0950 | bpb = 1.279
#  step 05/10 | loss = 1.5901 | bpb = 1.040
#  step 06/10 | loss = 1.1769 | bpb = 0.932
#  step 07/10 | loss = 0.8579 | bpb = 0.886
#  step 08/10 | loss = 0.5773 | bpb = 0.856
#  step 09/10 | loss = 0.4041 | bpb = 0.867
#  step 10/10 | loss = 0.3182 | bpb = 0.874
# -------- 結果 --------
# 回答: KaiRA のモットーは何ですか?
#  Hinweis: モットーは一緒に AI を学ぼう。
# KaiRA は毎年 11 月祭でポスター展示・AI デモ・
# bpb  : 0.870  (Δ = +1.567   ※マイナス=改善)
# ----------------------
#
# λ = 0.001
# 選択された文書 ID: [35, 12, 19, 2, 20, 8, 33, 23] ['サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'KaiRA は毎年 11 月祭でポスター展示・AI デモ・会誌販売を行う。', 'KaiRA は株式会社 Rist と株式会社スクラムサインから支援を受けている。', 'AI を学びたい学生や一緒に AI を開発したい学生を歓迎している。', '創設者の金子英樹は、難解な数式に挫折する学生のために KaiRA を立ち上げた。', '輪読会は毎週月曜・木曜の 18:40 から京都大学文学部教室とオンラインで開催される。', 'モデル学習の実験にかかる Google Colab Pro の料金は補助されます。', '入会ステップ 1 は connpass で輪読会に申し込み見学することである。']
# -------- Fine-Tuning --------
#  step 01/10 | loss = 0.2390 | bpb = 1.008
#  step 02/10 | loss = 0.7249 | bpb = 0.808
#  step 03/10 | loss = 0.3044 | bpb = 0.802
#  step 04/10 | loss = 0.2268 | bpb = 0.773
#  step 05/10 | loss = 0.1908 | bpb = 0.783
#  step 06/10 | loss = 0.1948 | bpb = 0.788
#  step 07/10 | loss = 0.1760 | bpb = 0.763
#  step 08/10 | loss = 0.1504 | bpb = 0.727
#  step 09/10 | loss = 0.1246 | bpb = 0.706
#  step 10/10 | loss = 0.1390 | bpb = 0.718
# -------- 結果 --------
# 回答: KaiRA のモットーは何ですか?
#  nobody knows what KaiRA can do until KaiRA tries. 難解な数式に挫折する学生のために KaiRAは創設された。
# 創設者の金
# bpb  : 0.716  (Δ = +1.722   ※マイナス=改善)
# ----------------------
#
# λ = 0.01
# 選択された文書 ID: [35, 12, 19, 2, 20, 8, 33, 23] ['サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'KaiRA は毎年 11 月祭でポスター展示・AI デモ・会誌販売を行う。', 'KaiRA は株式会社 Rist と株式会社スクラムサインから支援を受けている。', 'AI を学びたい学生や一緒に AI を開発したい学生を歓迎している。', '創設者の金子英樹は、難解な数式に挫折する学生のために KaiRA を立ち上げた。', '輪読会は毎週月曜・木曜の 18:40 から京都大学文学部教室とオンラインで開催される。', 'モデル学習の実験にかかる Google Colab Pro の料金は補助されます。', '入会ステップ 1 は connpass で輪読会に申し込み見学することである。']
# -------- Fine-Tuning --------
#  step 01/10 | loss = 0.1312 | bpb = 0.923
#  step 02/10 | loss = 0.2952 | bpb = 0.856
#  step 03/10 | loss = 0.2375 | bpb = 0.812
#  step 04/10 | loss = 0.2257 | bpb = 0.769
#  step 05/10 | loss = 0.1986 | bpb = 0.724
#  step 06/10 | loss = 0.1671 | bpb = 0.750
#  step 07/10 | loss = 0.1706 | bpb = 0.784
#  step 08/10 | loss = 0.1722 | bpb = 0.795
#  step 09/10 | loss = 0.1637 | bpb = 0.809
#  step 10/10 | loss = 0.1302 | bpb = 0.851
# -------- 結果 --------
# 回答: KaiRA のモットーは何ですか?
#  nobody knows. 創設者の金子英樹は毎年 11 月祭でポスター展示・AI デモ・会誌販売を行う。
# 創設者の金
# bpb  : 0.845  (Δ = +1.593   ※マイナス=改善)
# ----------------------
#
# λ = 0.1
# 選択された文書 ID: [35, 12, 19, 33, 2, 20, 35, 8] ['サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'KaiRA は毎年 11 月祭でポスター展示・AI デモ・会誌販売を行う。', 'KaiRA は株式会社 Rist と株式会社スクラムサインから支援を受けている。', 'モデル学習の実験にかかる Google Colab Pro の料金は補助されます。', 'AI を学びたい学生や一緒に AI を開発したい学生を歓迎している。', '創設者の金子英樹は、難解な数式に挫折する学生のために KaiRA を立ち上げた。', 'サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', '輪読会は毎週月曜・木曜の 18:40 から京都大学文学部教室とオンラインで開催される。']
# -------- Fine-Tuning --------
#  step 01/10 | loss = 0.1174 | bpb = 0.865
#  step 02/10 | loss = 0.1601 | bpb = 0.749
#  step 03/10 | loss = 0.1130 | bpb = 0.703
#  step 04/10 | loss = 0.1007 | bpb = 0.719
#  step 05/10 | loss = 0.1099 | bpb = 0.719
#  step 06/10 | loss = 0.0992 | bpb = 0.725
#  step 07/10 | loss = 0.0947 | bpb = 0.768
#  step 08/10 | loss = 0.0890 | bpb = 0.831
#  step 09/10 | loss = 0.0884 | bpb = 0.942
#  step 10/10 | loss = 0.0900 | bpb = 0.932
# -------- 結果 --------
# 回答: KaiRA のモットーは何ですか?
#  KaiRA のモットーは「KaiRA は毎年 11 月祭でポスター展示・AI デモ・会誌販売を行う。」です
# bpb  : 0.926  (Δ = +1.512   ※マイナス=改善)
# ----------------------
#
# λ = 1
# 選択された文書 ID: [35, 12, 35, 19, 12, 33, 35, 20] ['サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'KaiRA は毎年 11 月祭でポスター展示・AI デモ・会誌販売を行う。', 'サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'KaiRA は株式会社 Rist と株式会社スクラムサインから支援を受けている。', 'KaiRA は毎年 11 月祭でポスター展示・AI デモ・会誌販売を行う。', 'モデル学習の実験にかかる Google Colab Pro の料金は補助されます。', 'サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', '創設者の金子英樹は、難解な数式に挫折する学生のために KaiRA を立ち上げた。']
# -------- Fine-Tuning --------
#  step 01/10 | loss = 0.0905 | bpb = 1.132
#  step 02/10 | loss = 0.1346 | bpb = 0.844
#  step 03/10 | loss = 0.1048 | bpb = 0.748
#  step 04/10 | loss = 0.0779 | bpb = 0.699
#  step 05/10 | loss = 0.0905 | bpb = 0.709
#  step 06/10 | loss = 0.0798 | bpb = 0.743
#  step 07/10 | loss = 0.0729 | bpb = 0.781
#  step 08/10 | loss = 0.0797 | bpb = 0.790
#  step 09/10 | loss = 0.0792 | bpb = 0.816
#  step 10/10 | loss = 0.0761 | bpb = 0.840
# -------- 結果 --------
# 回答: KaiRA のモットーは何ですか?
#  KaiRA は毎年 11 月祭でポスター展示・AI デモ・会誌販売を行う。
# 会誌は毎年 11 月祭の
# bpb  : 0.840  (Δ = +1.598   ※マイナス=改善)
# ----------------------
#
# λ = 10
# 選択された文書 ID: [35, 35, 12, 35, 12, 35, 12, 35] ['サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'KaiRA は毎年 11 月祭でポスター展示・AI デモ・会誌販売を行う。', 'サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'KaiRA は毎年 11 月祭でポスター展示・AI デモ・会誌販売を行う。', 'サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'KaiRA は毎年 11 月祭でポスター展示・AI デモ・会誌販売を行う。', 'サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。']
# -------- Fine-Tuning --------
#  step 01/10 | loss = 0.0587 | bpb = 0.797
#  step 02/10 | loss = 0.0536 | bpb = 0.799
#  step 03/10 | loss = 0.0497 | bpb = 0.907
#  step 04/10 | loss = 0.0436 | bpb = 1.053
#  step 05/10 | loss = 0.0422 | bpb = 1.189
#  step 06/10 | loss = 0.0438 | bpb = 1.267
#  step 07/10 | loss = 0.0435 | bpb = 1.352
#  step 08/10 | loss = 0.0428 | bpb = 1.407
#  step 09/10 | loss = 0.0413 | bpb = 1.479
#  step 10/10 | loss = 0.0405 | bpb = 1.531
# -------- 結果 --------
# 回答: KaiRA のモットーは何ですか?
#  KaiRA は毎年 11 月祭でポスター展示・AI デモ・会誌販売を行う。
# サークルのモットーは「毎年 1
# bpb  : 1.535  (Δ = +0.903   ※マイナス=改善)
# ----------------------
#
# λ = 100
# 選択された文書 ID: [35, 35, 35, 35, 35, 35, 35, 35] ['サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。', 'サークルのモットーは「楽しい環境で一緒に AI を学ぼう」です。']
# -------- Fine-Tuning --------
#  step 01/10 | loss = 0.0403 | bpb = 1.562
#  step 02/10 | loss = 0.0321 | bpb = 1.555
#  step 03/10 | loss = 0.0299 | bpb = 1.622
#  step 04/10 | loss = 0.0149 | bpb = 1.718
#  step 05/10 | loss = 0.2160 | bpb = 1.847
#  step 06/10 | loss = 0.0438 | bpb = 1.948
#  step 07/10 | loss = 0.0183 | bpb = 2.115
#  step 08/10 | loss = 0.0270 | bpb = 2.206
#  step 09/10 | loss = 0.0322 | bpb = 2.084
#  step 10/10 | loss = 0.1674 | bpb = 2.255
# -------- 結果 --------
# 回答: KaiRA のモットーは何ですか?
#  楽しい環境で一緒に AI を学ぼう!
# KaiRA は毎年 11 月祭でポスター展示・AI デモ・会誌販売
# bpb  : 2.257  (Δ = +0.180   ※マイナス=改善)
# ----------------------
